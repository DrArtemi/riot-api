# %%
import requests as rq
import datetime
import math
API_KEY = "0TvQnueqKa5mxJntVWt0w4LpLfEkrV1Ta8rQBb9Z"
headers = {
    "x-api-key": API_KEY
}
# API_KEY = "RGAPI-d6e47b76-99e1-47a1-a692-0d7f6398856c"
# headers = {
#     "X-Riot-Token": API_KEY
# }

# %%
# Get tournaments
params = dict(
    hl="en-US",
    leagueId=98767991302996019
)
league_tournaments = rq.get(
    url="https://esports-api.lolesports.com/persisted/gw/getTournamentsForLeague",
    headers=headers,
    params=params
)
league_tournaments.json()['data']['leagues'][0]['tournaments']
# Out:
# [{'id': '100205575629449176',
#   'slug': 'eu_2018_summer',
#   'startDate': '2018-06-15',
#   'endDate': '2018-09-16'},
#  {'id': '101383793622305540',
#   'slug': 'lec_2019_spring',
#   'startDate': '2019-01-18',
#   'endDate': '2019-04-14'},
#  {'id': '102147201778412187',
#   'slug': 'lec_2019_summer',
#   'startDate': '2019-06-07',
#   'endDate': '2019-09-20'},
#  {'id': '103462459318635408',
#   'slug': 'lec_2020_split1',
#   'startDate': '2020-01-24',
#   'endDate': '2020-04-27'},
#  {'id': '104169295253189561',
#   'slug': 'lec_summer_2020',
#   'startDate': '2020-06-11',
#   'endDate': '2020-09-07'},
#  {'id': '105522958532258735',
#   'slug': 'lec_2021_split1',
#   'startDate': '2021-01-04',
#   'endDate': '2021-04-11'},
#  {'id': '106269680921022418',
#   'slug': 'lec_2021_summer',
#   'startDate': '2021-06-11',
#   'endDate': '2021-08-30'},
#  {'id': '107417059262120466',
#   'slug': 'lec_2022_spring',
#   'startDate': '2022-01-01',
#   'endDate': '2022-05-15'},
#  {'id': '99322214712278618',
#   'slug': 'eu_2018_spring',
#   'startDate': '2018-01-19',
#   'endDate': '2018-04-08'}]

# %%
# Get standings for tournaments
params = dict(
    hl="en-US",
    tournamentId=107417059262120466,
)
tournament_standings = rq.get(
    url="https://esports-api.lolesports.com/persisted/gw/getStandings",
    headers=headers,
    params=params
)
standings = tournament_standings.json()['data']['standings'][0]['stages']
standings
# Out:
# [{'name': 'Play In Groups',
#   'type': 'groups',
#   'slug': 'play_in_groups',
#   'sections': [{'name': 'Group A',
#     'matches': [{'id': '103936903249772876',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838414',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903249838416',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903249838418',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838420',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903249838422',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838424',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903249838426',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838428',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838430',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903249838432',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903249838434',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'record': {'wins': 5, 'losses': 1}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'record': {'wins': 4, 'losses': 2}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '103877879209300619',
#         'slug': 'vipers-inc',
#         'name': 'Vipers Inc',
#         'code': 'VIP',
#         'image': 'http://static.lolesports.com/teams/1585050644953_220px-Vipers_Inclogo_square.png',
#         'record': {'wins': 2, 'losses': 4}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '102787200130988976',
#         'slug': 'asus-rog-elite',
#         'name': 'ASUS ROG Elite',
#         'code': 'ASUS',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#         'record': {'wins': 1, 'losses': 5}}]}]},
#    {'name': 'Group B',
#     'matches': [{'id': '103936903250493796',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903250493798',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903250493800',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903250493802',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250493804',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559342',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559344',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559346',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903250559348',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559350',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559352',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903250559354',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'record': {'wins': 5, 'losses': 1}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'record': {'wins': 4, 'losses': 2}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '103878020539746273',
#         'slug': 'egn-esports',
#         'name': 'EGN Esports',
#         'code': 'EGN',
#         'image': 'http://static.lolesports.com/teams/LPLOL_EGN-Logo1.png',
#         'record': {'wins': 3, 'losses': 3}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '103877951616192529',
#         'slug': 'cyber-gaming',
#         'name': 'Cyber Gaming',
#         'code': 'CG',
#         'image': 'http://static.lolesports.com/teams/1585051749524_220px-Cyber_Gaminglogo_square.png',
#         'record': {'wins': 0, 'losses': 6}}]}]},
#    {'name': 'Group C',
#     'matches': [{'id': '103936903251149180',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214718',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251214720',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251214722',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214724',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214726',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251214728',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214730',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214732',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214734',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251214736',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251214738',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'record': {'wins': 5, 'losses': 1}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'record': {'wins': 4, 'losses': 2}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '103877908090914662',
#         'slug': 'kenty',
#         'name': 'Kenty',
#         'code': 'KEN',
#         'image': 'http://static.lolesports.com/teams/1585051086000_220px-Kentylogo_square.png',
#         'record': {'wins': 2, 'losses': 4}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '102787200132955066',
#         'slug': 'for-the-win-esports',
#         'name': 'For The Win Esports',
#         'code': 'FTW',
#         'image': 'http://static.lolesports.com/teams/LPLOL_FTW-Logo1.png',
#         'record': {'wins': 1, 'losses': 5}}]}]},
#    {'name': 'Group D',
#     'matches': [{'id': '103936903251804564',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804566',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804568',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804570',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251804572',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251804574',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804576',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251804578',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804580',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903251804582',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804584',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903251804586',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': [],
#       'teams': [{'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'record': {'wins': 5, 'losses': 1}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'record': {'wins': 4, 'losses': 2}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '102787200149928963',
#         'slug': 'we-love-gaming',
#         'name': 'We Love Gaming',
#         'code': 'WLG',
#         'image': 'http://static.lolesports.com/teams/WLGlogo.png',
#         'record': {'wins': 3, 'losses': 3}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '103877925817094140',
#         'slug': 'pigsports',
#         'name': 'PIGSPORTS',
#         'code': 'PIG',
#         'image': 'http://static.lolesports.com/teams/PIGSPORTS_PIG-Logo1.png',
#         'record': {'wins': 0, 'losses': 6}}]}]}]},
#  {'name': 'Play In Knockouts',
#   'type': 'bracket',
#   'slug': 'play_in_elim',
#   'sections': [{'name': 'Play In Knockouts',
#     'matches': [{'id': '103936903252591021',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': [],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}},
#        {'id': '103877976717529187',
#         'slug': 'intrepid-fox-gaming',
#         'name': 'Intrepid Fox Gaming',
#         'code': 'IF',
#         'image': 'http://static.lolesports.com/teams/1585052132267_220px-Intrepid_Fox_Gaminglogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903252591025',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': [],
#       'teams': [{'id': '103877756742242918',
#         'slug': 'racoon',
#         'name': 'Racoon',
#         'code': 'RCN',
#         'image': 'http://static.lolesports.com/teams/1585048776551_220px-Racoon_(Italian_Team)logo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]},
#      {'id': '103936903252591029',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': [],
#       'teams': [{'id': '103935642731826448',
#         'slug': 'sector-one',
#         'name': 'Sector One',
#         'code': 'S1',
#         'image': 'http://static.lolesports.com/teams/1641288621852_1024x1024_sector_one_nameless_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}},
#        {'id': '102787200145472495',
#         'slug': 'defusekids',
#         'name': 'Defusekids',
#         'code': 'DKI',
#         'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/defusekids-finmimok.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]},
#      {'id': '103936903252591033',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': [],
#       'teams': [{'id': '103935421249833954',
#         'slug': 'mad-lions-madrid',
#         'name': 'MAD Lions Madrid',
#         'code': 'MADM',
#         'image': 'http://static.lolesports.com/teams/SL_MADM-Logo_white.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]}],
#     'rankings': []}]},
#  {'name': 'Groups',
#   'type': 'groups',
#   'slug': 'groups',
#   'sections': [{'name': 'Group A',
#     'matches': [{'id': '103936903254163907',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163909',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163911',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903254163913',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163915',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903254163917',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163919',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163921',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903254163923',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903254163925',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903254163927',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903254163929',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877589042434434',
#         'slug': 'gamerlegion',
#         'name': 'GamerLegion',
#         'code': 'GL',
#         'image': 'http://static.lolesports.com/teams/1585046217463_220px-Team_GamerLegionlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103877774634323825',
#         'slug': 'ydn-gamers',
#         'name': 'YDN Gamers',
#         'code': 'YDN',
#         'image': 'http://static.lolesports.com/teams/1587638409857_LOGO_YDN_-trasp.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '104089647646181969',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod', 'isSpoiler'],
#       'teams': [{'id': '103877589042434434',
# ...
#         'slug': 'movistar-riders',
#         'name': 'Movistar Riders',
#         'code': 'MRS',
#         'image': 'http://static.lolesports.com/teams/1585046777741_220px-Movistar_Riderslogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '103877625775457850',
#         'slug': 'movistar-riders',
#         'name': 'Movistar Riders',
#         'code': 'MRS',
#         'image': 'http://static.lolesports.com/teams/1585046777741_220px-Movistar_Riderslogo_square.png',
#         'record': {'wins': 6, 'losses': 2}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'record': {'wins': 4, 'losses': 3}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '103877554248683116',
#         'slug': 'schalke-04-evolution',
#         'name': 'Schalke 04 Evolution',
#         'code': 'S04E',
#         'image': 'http://static.lolesports.com/teams/S04_Standard_Logo1.png',
#         'record': {'wins': 4, 'losses': 3}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '103877891572305836',
#         'slug': 'team-singularity',
#         'name': 'Team Singularity',
#         'code': 'SNG',
#         'image': 'http://static.lolesports.com/teams/NLC_SNG-light.png',
#         'record': {'wins': 0, 'losses': 6}}]}]},
#    {'name': 'Group D',
#     'matches': [{'id': '103936903255867915',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903255867917',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867919',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867921',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867923',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903255867925',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867927',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867929',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867931',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903255867933',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '103936903255867935',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '103936903255867937',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'record': {'wins': 5, 'losses': 1}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'record': {'wins': 4, 'losses': 2}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '103935567188806885',
#         'slug': 'energypot-wizards',
#         'name': 'Energypot Wizards',
#         'code': 'EWIZ',
#         'image': 'http://static.lolesports.com/teams/1585930892362_Energypot_Wizardslogo_square.png',
#         'record': {'wins': 3, 'losses': 3}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '102787200129022886',
#         'slug': 'esuba',
#         'name': 'eSuba',
#         'code': 'ESB',
#         'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#         'record': {'wins': 0, 'losses': 6}}]}]}]},
#  {'name': 'Knockouts',
#   'type': 'bracket',
#   'slug': 'elim',
#   'sections': [{'name': 'Quarterfinals',
#     'matches': [{'id': '103936903256588836',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200120306562',
#         'slug': 'mousesports',
#         'name': 'Mousesports',
#         'code': 'MOUZ',
#         'image': 'http://static.lolesports.com/teams/1639486346996_PRM_MOUZ-FullColorDarkBG.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935530333072898',
#         'slug': 'ago-rogue',
#         'name': 'AGO Rogue',
#         'code': 'RGO',
#         'image': 'http://static.lolesports.com/teams/1585930330127_AGO_ROGUElogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]},
#      {'id': '103936903256588840',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200155434012',
#         'slug': 'jdxl',
#         'name': 'JD|XL',
#         'code': 'JDXL',
#         'image': 'http://static.lolesports.com/teams/1641489535868_jdxl.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103877675241047720',
#         'slug': 'ldlc-ol',
#         'name': 'LDLC OL',
#         'code': 'LDLC',
#         'image': 'http://static.lolesports.com/teams/LFL-LDLC-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]},
#      {'id': '103936903256588844',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '102787200134790084',
#         'slug': 'hma-fnatic-rising',
#         'name': 'HMA Fnatic Rising',
#         'code': 'FNCR',
#         'image': 'http://static.lolesports.com/teams/NLC_FNCR-logo.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}},
#        {'id': '103877625775457850',
#         'slug': 'movistar-riders',
#         'name': 'Movistar Riders',
#         'code': 'MRS',
#         'image': 'http://static.lolesports.com/teams/1585046777741_220px-Movistar_Riderslogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]},
#      {'id': '103936903256588848',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}},
#        {'id': '103935468920814040',
#         'slug': 'gamersorigin',
#         'name': 'GamersOrigin',
#         'code': 'GO',
#         'image': 'http://static.lolesports.com/teams/1588178480033_logoGO_2020_G_Blanc.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}}]}],
#     'rankings': []},
#    {'name': 'Semifinals',
#     'matches': [{'id': '103936903256588852',
#       'state': 'completed',
#       'previousMatchIds': ['103936903256588836', '103936903256588840'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877675241047720',
#         'slug': 'ldlc-ol',
#         'name': 'LDLC OL',
#         'code': 'LDLC',
#         'image': 'http://static.lolesports.com/teams/LFL-LDLC-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 2}},
#        {'id': '103935530333072898',
#         'slug': 'ago-rogue',
#         'name': 'AGO Rogue',
#         'code': 'RGO',
#         'image': 'http://static.lolesports.com/teams/1585930330127_AGO_ROGUElogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}}]},
#      {'id': '103936903256588856',
#       'state': 'completed',
#       'previousMatchIds': ['103936903256588844', '103936903256588848'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877625775457850',
#         'slug': 'movistar-riders',
#         'name': 'Movistar Riders',
#         'code': 'MRS',
#         'image': 'http://static.lolesports.com/teams/1585046777741_220px-Movistar_Riderslogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 2}}]}],
#     'rankings': []},
#    {'name': 'Finals',
#     'matches': [{'id': '103936903256588860',
#       'state': 'completed',
#       'previousMatchIds': ['103936903256588852', '103936903256588856'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '103877675241047720',
#         'slug': 'ldlc-ol',
#         'name': 'LDLC OL',
#         'code': 'LDLC',
#         'image': 'http://static.lolesports.com/teams/LFL-LDLC-logo.png',
#         'result': {'outcome': 'win', 'gameWins': 3}},
#        {'id': '103935523328473675',
#         'slug': 'k1ck-neosurf',
#         'name': 'K1CK Neosurf',
#         'code': 'K1',
#         'image': 'http://static.lolesports.com/teams/1585930223604_K1ck_Neosurflogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]}],
#     'rankings': []}]}]

# %%
# Get all matches from standings ?
regular_season = [s for s in standings if s["slug"] == "play_in_groups"][0]
regular_season = regular_season["sections"][0]
matches = regular_season["matches"]
for match in matches:
    winner = False
    for team in match["teams"]:
        if team["result"]["outcome"] == "win":
            winner = True
            break
    if not winner:
        print(match)
matches[0]
# Out:
# {'id': '103936903249772876',
#  'state': 'completed',
#  'previousMatchIds': None,
#  'flags': [],
#  'teams': [{'id': '102787200129022886',
#    'slug': 'esuba',
#    'name': 'eSuba',
#    'code': 'ESB',
#    'image': 'http://static.lolesports.com/teams/1629209489523_esuba_full_pos.png',
#    'result': {'outcome': 'win', 'gameWins': 1}},
#   {'id': '102787200130988976',
#    'slug': 'asus-rog-elite',
#    'name': 'ASUS ROG Elite',
#    'code': 'ASUS',
#    'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/asus-rog-elite-iouou6l.png',
#    'result': {'outcome': 'loss', 'gameWins': 0}}]}

# %%
mydate = datetime.datetime.now()
minute = datetime.timedelta(minutes=180)
print(mydate, minute)
mydate_final = (mydate - minute).strftime("%Y-%m-%dT%H:%M:%S")
print(mydate_final)
head = mydate_final[:-2]
tail = round(int(mydate_final[-2:]), -1)
sec = str(tail)
if len(sec) < 2:
    sec = '0' + sec
mydate_final = head + str(sec) + 'Z'
mydate_final
# Out:
# 2022-04-24 16:40:58.221872 3:00:00
# 2022-04-24T13:40:58
# '2022-04-24T13:40:60Z'

# %%
match = matches[0]
params = dict(
    startingTime=mydate_final,
)
# match 105568157422015211
# https://feed.lolesports.com/livestats/v1/details/{gameId}
r = rq.get(
    url=f"https://feed.lolesports.com/livestats/v1/window/{int(match['id']) + 1}",
    headers=headers,
    params=params
)
r
# frames = r.json()["frames"]
# frames
# Out:
# <Response [400]>

# %%
match

# %%
len(frames)
# [f["rfc460Timestamp"] for f in frames]
last_frame = frames[-1]
last_frame
# Out:
# {'rfc460Timestamp': '2021-01-19T22:56:12.631Z',
#  'gameState': 'finished',
#  'blueTeam': {'totalGold': 55328,
#   'inhibitors': 3,
#   'towers': 11,
#   'barons': 1,
#   'totalKills': 15,
#   'dragons': ['cloud', 'cloud'],
#   'participants': [{'participantId': 1,
#     'totalGold': 9810,
#     'level': 14,
#     'kills': 0,
#     'deaths': 3,
#     'assists': 6,
#     'creepScore': 196,
#     'currentHealth': 1081,
#     'maxHealth': 2426},
#    {'participantId': 2,
#     'totalGold': 11463,
#     'level': 14,
#     'kills': 5,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 187,
#     'currentHealth': 1368,
#     'maxHealth': 1872},
#    {'participantId': 3,
#     'totalGold': 13461,
#     'level': 16,
#     'kills': 5,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 282,
#     'currentHealth': 319,
#     'maxHealth': 1862},
#    {'participantId': 4,
#     'totalGold': 13778,
#     'level': 15,
#     'kills': 5,
#     'deaths': 0,
#     'assists': 4,
#     'creepScore': 268,
#     'currentHealth': 814,
#     'maxHealth': 1803},
#    {'participantId': 5,
#     'totalGold': 6816,
#     'level': 11,
#     'kills': 0,
#     'deaths': 1,
#     'assists': 5,
#     'creepScore': 38,
#     'currentHealth': 361,
#     'maxHealth': 1939}]},
#  'redTeam': {'totalGold': 42132,
#   'inhibitors': 0,
#   'towers': 0,
#   'barons': 0,
#   'totalKills': 6,
#   'dragons': ['infernal', 'mountain'],
#   'participants': [{'participantId': 6,
#     'totalGold': 8258,
#     'level': 13,
#     'kills': 2,
#     'deaths': 6,
#     'assists': 2,
#     'creepScore': 161,
#     'currentHealth': 2176,
#     'maxHealth': 2834},
#    {'participantId': 7,
#     'totalGold': 8136,
#     'level': 13,
#     'kills': 0,
#     'deaths': 4,
#     'assists': 4,
#     'creepScore': 182,
#     'currentHealth': 9,
#     'maxHealth': 1865},
#    {'participantId': 8,
#     'totalGold': 8847,
#     'level': 14,
#     'kills': 0,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 219,
#     'currentHealth': 902,
#     'maxHealth': 1670},
#    {'participantId': 9,
#     'totalGold': 11246,
#     'level': 13,
#     'kills': 4,
#     'deaths': 0,
#     'assists': 1,
#     'creepScore': 239,
#     'currentHealth': 744,
#     'maxHealth': 1643},
#    {'participantId': 10,
#     'totalGold': 5645,
#     'level': 11,
#     'kills': 0,
#     'deaths': 4,
#     'assists': 5,
#     'creepScore': 30,
#     'currentHealth': 0,
#     'maxHealth': 1780}]}}

# %%
params = dict(
    startingTime=mydate_final,
)

r = rq.get(
    url=f"https://feed.lolesports.com/livestats/v1/window/{int(match['id']) + 1}",
    headers=headers,
    params=params
)
game_data = r.json()
game = game_data["gameMetadata"]
frames_game = game_data["frames"]

# %%
game

# %%
# [f["rfc460Timestamp"] for f in frames_game]
last_frame_game = frames_game[-1]
last_frame_game

# %%
merged_last_frame = last_frame.copy()
merged_last_frame.update(last_frame_game)
merged_last_frame

# %%
# Merge data from match details + game window => team stats + players stats
# Last frame = final state of the game
game["final_state"] = merged_last_frame
game

# %%
game.keys()

# %%
# Refacto tout pour que ca soit plus propre maintenant
# Blue team
#   team data
#   players
#       player data
# Red team
#   team data
#   players
#       player data
from copy import deepcopy
g_data = deepcopy(game)

# %%
# 2009-07-12 11:03:12+02:00

params = dict(
    hl="en-US",
    tournamentId=103936903203607374,
)
r = rq.get("https://esports-api.lolesports.com/persisted/gw/getCompletedEvents", headers=headers, params=params)
r.json()

# %%
r.json()

# %%
params = {
    "gameId": 106926282335055890,
    # "startingTime": mydate_final
}

# r = rq.get("https://europe.api.riotgames.com/riot/account/v1/accounts/me", headers=headers)
r = rq.get("https://europe.api.riotgames.com/lol/match/v5/matches/106926282335055885", headers=headers)
r

# %%
r.json()

# %%
params = {
    "startingTime": mydate_final
}
r = rq.get("https://feed.lolesports.com/livestats/v1/details/106926282335055890", headers=headers, params=params)
r

# %%
r.json()
