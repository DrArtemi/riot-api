# %%
import requests as rq
import datetime
import math
API_KEY = "0TvQnueqKa5mxJntVWt0w4LpLfEkrV1Ta8rQBb9Z"
headers = {
    "x-api-key": API_KEY
}
# API_KEY = "RGAPI-d6e47b76-99e1-47a1-a692-0d7f6398856c"
# headers = {
#     "X-Riot-Token": API_KEY
# }

# %%
# Get tournaments
params = dict(
    hl="en-US",
    leagueId=98767991302996019
)
league_tournaments = rq.get(
    url="https://esports-api.lolesports.com/persisted/gw/getTournamentsForLeague",
    headers=headers,
    params=params
)
league_tournaments.json()['data']['leagues'][0]['tournaments']
# Out:
# [{'id': '100205575629449176',
#   'slug': 'eu_2018_summer',
#   'startDate': '2018-06-15',
#   'endDate': '2018-09-16'},
#  {'id': '101383793622305540',
#   'slug': 'lec_2019_spring',
#   'startDate': '2019-01-18',
#   'endDate': '2019-04-14'},
#  {'id': '102147201778412187',
#   'slug': 'lec_2019_summer',
#   'startDate': '2019-06-07',
#   'endDate': '2019-09-20'},
#  {'id': '103462459318635408',
#   'slug': 'lec_2020_split1',
#   'startDate': '2020-01-24',
#   'endDate': '2020-04-27'},
#  {'id': '104169295253189561',
#   'slug': 'lec_summer_2020',
#   'startDate': '2020-06-11',
#   'endDate': '2020-09-07'},
#  {'id': '105522958532258735',
#   'slug': 'lec_2021_split1',
#   'startDate': '2021-01-04',
#   'endDate': '2021-04-11'},
#  {'id': '106269680921022418',
#   'slug': 'lec_2021_summer',
#   'startDate': '2021-06-11',
#   'endDate': '2021-08-30'},
#  {'id': '107417059262120466',
#   'slug': 'lec_2022_spring',
#   'startDate': '2022-01-01',
#   'endDate': '2022-05-15'},
#  {'id': '99322214712278618',
#   'slug': 'eu_2018_spring',
#   'startDate': '2018-01-19',
#   'endDate': '2018-04-08'}]

# %%
# Get standings for tournaments
params = dict(
    hl="en-US",
    tournamentId=107417059262120466,
)
tournament_standings = rq.get(
    url="https://esports-api.lolesports.com/persisted/gw/getStandings",
    headers=headers,
    params=params
)
standings = tournament_standings.json()['data']['standings'][0]['stages']
standings
# Out:
# [{'name': 'Regular Season',
#   'type': 'groups',
#   'slug': 'regular_season',
#   'sections': [{'name': 'Regular Season',
#     'matches': [{'id': '107417059263300117',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300119',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300121',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300123',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300125',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300127',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300129',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300131',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300133',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300135',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300137',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300139',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300141',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300143',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300145',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300147',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300149',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300151',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300153',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300155',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300157',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300159',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300161',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300163',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300165',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300167',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300169',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263300171',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300173',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263300175',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365713',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365715',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365717',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365719',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365721',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365723',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365725',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365727',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365729',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365731',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365733',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365735',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365737',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365739',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365741',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365743',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365745',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365747',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365749',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365751',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365753',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365755',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365757',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365759',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365761',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365763',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365765',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365767',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365769',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365771',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365773',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365775',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365777',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365779',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365781',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365783',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365785',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365787',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365789',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365791',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365793',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263365795',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365797',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365799',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263365801',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
# ...
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431347',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263431349',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263431351',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431353',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431355',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263431357',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431359',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431361',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263431363',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'win', 'gameWins': 1}},
#        {'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]},
#      {'id': '107417059263431365',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]},
#      {'id': '107417059263431367',
#       'state': 'completed',
#       'previousMatchIds': None,
#       'flags': ['hasVod'],
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 1}}]}],
#     'rankings': [{'ordinal': 1,
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'record': {'wins': 14, 'losses': 4}}]},
#      {'ordinal': 2,
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'record': {'wins': 13, 'losses': 5}}]},
#      {'ordinal': 3,
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'record': {'wins': 12, 'losses': 6}}]},
#      {'ordinal': 4,
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'record': {'wins': 11, 'losses': 7}}]},
#      {'ordinal': 5,
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'record': {'wins': 9, 'losses': 9}}]},
#      {'ordinal': 6,
#       'teams': [{'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'record': {'wins': 9, 'losses': 9}}]},
#      {'ordinal': 7,
#       'teams': [{'id': '103461966965149786',
#         'slug': 'mad-lions',
#         'name': 'MAD Lions',
#         'code': 'MAD',
#         'image': 'http://static.lolesports.com/teams/1631819614211_mad-2021-worlds.png',
#         'record': {'wins': 8, 'losses': 10}}]},
#      {'ordinal': 8,
#       'teams': [{'id': '101383793567806688',
#         'slug': 'sk-gaming',
#         'name': 'SK Gaming',
#         'code': 'SK',
#         'image': 'http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png',
#         'record': {'wins': 7, 'losses': 11}}]},
#      {'ordinal': 9,
#       'teams': [{'id': '107563714667537640',
#         'slug': 'team-bds',
#         'name': 'Team BDS',
#         'code': 'BDS',
#         'image': 'http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png',
#         'record': {'wins': 4, 'losses': 14}}]},
#      {'ordinal': 10,
#       'teams': [{'id': '101383793569248484',
#         'slug': 'astralis',
#         'name': 'Astralis',
#         'code': 'AST',
#         'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#         'record': {'wins': 3, 'losses': 15}}]}]}]},
#  {'name': 'Playoffs',
#   'type': 'bracket',
#   'slug': 'playoffs',
#   'sections': [{'name': 'Upper Bracket - Round 1',
#     'matches': [{'id': '107417293272826572',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 3}},
#        {'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}}]},
#      {'id': '107417293272826578',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 3}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 1}}]}],
#     'rankings': []},
#    {'name': 'Lower Bracket - Round 1',
#     'matches': [{'id': '107417293272826584',
#       'state': 'completed',
#       'previousMatchIds': [],
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793572656373',
#         'slug': 'excel',
#         'name': 'EXCEL',
#         'code': 'XL',
#         'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#         'result': {'outcome': 'loss', 'gameWins': 2}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'win', 'gameWins': 3}}]}],
#     'rankings': []},
#    {'name': 'Upper Bracket - Finals',
#     'matches': [{'id': '107417293272826590',
#       'state': 'completed',
#       'previousMatchIds': ['107417293272826572', '107417293272826578'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'win', 'gameWins': 3}},
#        {'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 2}}]}],
#     'rankings': []},
#    {'name': 'Lower Bracket - Round 2',
#     'matches': [{'id': '107417293272826596',
#       'state': 'completed',
#       'previousMatchIds': ['107417293272826584'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 3}},
#        {'id': '99322214695067838',
#         'slug': 'team-vitality',
#         'name': 'Team Vitality',
#         'code': 'VIT',
#         'image': 'http://static.lolesports.com/teams/Vitality-logo-color-outline-rgb.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}}]}],
#     'rankings': []},
#    {'name': 'Lower Bracket - Round 3',
#     'matches': [{'id': '107417293272826602',
#       'state': 'completed',
#       'previousMatchIds': ['107417293272826596'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991940181526',
#         'slug': 'misfits-gaming',
#         'name': 'Misfits Gaming',
#         'code': 'MSF',
#         'image': 'http://static.lolesports.com/teams/1592591419157_MisfitsMSF-01-FullonDark.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 3}}]}],
#     'rankings': []},
#    {'name': 'Lower Bracket - Finals',
#     'matches': [{'id': '107417293272826608',
#       'state': 'completed',
#       'previousMatchIds': ['107417293272826590', '107417293272826602'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '98767991866488695',
#         'slug': 'fnatic',
#         'name': 'Fnatic',
#         'code': 'FNC',
#         'image': 'http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 3}}]}],
#     'rankings': []},
#    {'name': 'Finals',
#     'matches': [{'id': '107417293272826614',
#       'state': 'completed',
#       'previousMatchIds': ['107417293272826590', '107417293272826608'],
#       'flags': ['hasVod'],
#       'teams': [{'id': '101383793574360315',
#         'slug': 'rogue',
#         'name': 'Rogue',
#         'code': 'RGE',
#         'image': 'http://static.lolesports.com/teams/1631819715136_rge-2021-worlds.png',
#         'result': {'outcome': 'loss', 'gameWins': 0}},
#        {'id': '98767991926151025',
#         'slug': 'g2-esports',
#         'name': 'G2 Esports',
#         'code': 'G2',
#         'image': 'http://static.lolesports.com/teams/G2-FullonDark.png',
#         'result': {'outcome': 'win', 'gameWins': 3}}]}],
#     'rankings': []}]}]

# %%
# Get all matches from standings ?
regular_season = [s for s in standings if s["slug"] == "regular_season"][0]
regular_season = regular_season["sections"][0]
matches = regular_season["matches"]
for match in matches:
    winner = False
    for team in match["teams"]:
        if team["result"]["outcome"] == "win":
            winner = True
            break
    if not winner:
        print(match)
matches[0]
# Out:
# {'id': '107417059263300117',
#  'state': 'completed',
#  'previousMatchIds': None,
#  'flags': ['hasVod'],
#  'teams': [{'id': '101383793569248484',
#    'slug': 'astralis',
#    'name': 'Astralis',
#    'code': 'AST',
#    'image': 'http://static.lolesports.com/teams/AST-FullonDark.png',
#    'result': {'outcome': 'loss', 'gameWins': 0}},
#   {'id': '101383793572656373',
#    'slug': 'excel',
#    'name': 'EXCEL',
#    'code': 'XL',
#    'image': 'http://static.lolesports.com/teams/Excel_FullColor2.png',
#    'result': {'outcome': 'win', 'gameWins': 1}}]}

# %%
mydate = datetime.datetime.now()
minute = datetime.timedelta(minutes=180)
print(mydate, minute)
mydate_final = (mydate - minute).strftime("%Y-%m-%dT%H:%M:%S")
print(mydate_final)
head = mydate_final[:-2]
tail = round(int(mydate_final[-2:]), -1)
sec = str(tail)
if len(sec) < 2:
    sec = '0' + sec
mydate_final = head + str(sec) + 'Z'
mydate_final
# Out:
# 2022-04-24 18:18:52.236299 3:00:00
# 2022-04-24T15:18:52
# '2022-04-24T15:18:50Z'

# %%
match = matches[0]
params = dict(
    startingTime=mydate_final,
)
# match 105568157422015211
# https://feed.lolesports.com/livestats/v1/details/{gameId}
r = rq.get(
    url=f"https://feed.lolesports.com/livestats/v1/window/{int(match['id']) + 1}",
    headers=headers,
    params=params
)
r
# frames = r.json()["frames"]
# frames
# Out:
# <Response [200]>

# %%
match

# %%
len(frames)
# [f["rfc460Timestamp"] for f in frames]
last_frame = frames[-1]
last_frame
# Out:
# {'rfc460Timestamp': '2021-01-19T22:56:12.631Z',
#  'gameState': 'finished',
#  'blueTeam': {'totalGold': 55328,
#   'inhibitors': 3,
#   'towers': 11,
#   'barons': 1,
#   'totalKills': 15,
#   'dragons': ['cloud', 'cloud'],
#   'participants': [{'participantId': 1,
#     'totalGold': 9810,
#     'level': 14,
#     'kills': 0,
#     'deaths': 3,
#     'assists': 6,
#     'creepScore': 196,
#     'currentHealth': 1081,
#     'maxHealth': 2426},
#    {'participantId': 2,
#     'totalGold': 11463,
#     'level': 14,
#     'kills': 5,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 187,
#     'currentHealth': 1368,
#     'maxHealth': 1872},
#    {'participantId': 3,
#     'totalGold': 13461,
#     'level': 16,
#     'kills': 5,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 282,
#     'currentHealth': 319,
#     'maxHealth': 1862},
#    {'participantId': 4,
#     'totalGold': 13778,
#     'level': 15,
#     'kills': 5,
#     'deaths': 0,
#     'assists': 4,
#     'creepScore': 268,
#     'currentHealth': 814,
#     'maxHealth': 1803},
#    {'participantId': 5,
#     'totalGold': 6816,
#     'level': 11,
#     'kills': 0,
#     'deaths': 1,
#     'assists': 5,
#     'creepScore': 38,
#     'currentHealth': 361,
#     'maxHealth': 1939}]},
#  'redTeam': {'totalGold': 42132,
#   'inhibitors': 0,
#   'towers': 0,
#   'barons': 0,
#   'totalKills': 6,
#   'dragons': ['infernal', 'mountain'],
#   'participants': [{'participantId': 6,
#     'totalGold': 8258,
#     'level': 13,
#     'kills': 2,
#     'deaths': 6,
#     'assists': 2,
#     'creepScore': 161,
#     'currentHealth': 2176,
#     'maxHealth': 2834},
#    {'participantId': 7,
#     'totalGold': 8136,
#     'level': 13,
#     'kills': 0,
#     'deaths': 4,
#     'assists': 4,
#     'creepScore': 182,
#     'currentHealth': 9,
#     'maxHealth': 1865},
#    {'participantId': 8,
#     'totalGold': 8847,
#     'level': 14,
#     'kills': 0,
#     'deaths': 1,
#     'assists': 4,
#     'creepScore': 219,
#     'currentHealth': 902,
#     'maxHealth': 1670},
#    {'participantId': 9,
#     'totalGold': 11246,
#     'level': 13,
#     'kills': 4,
#     'deaths': 0,
#     'assists': 1,
#     'creepScore': 239,
#     'currentHealth': 744,
#     'maxHealth': 1643},
#    {'participantId': 10,
#     'totalGold': 5645,
#     'level': 11,
#     'kills': 0,
#     'deaths': 4,
#     'assists': 5,
#     'creepScore': 30,
#     'currentHealth': 0,
#     'maxHealth': 1780}]}}

# %%
params = dict(
    startingTime=mydate_final,
)

r = rq.get(
    url=f"https://feed.lolesports.com/livestats/v1/window/{int(match['id']) + 1}",
    headers=headers,
    params=params
)
game_data = r.json()
game = game_data["gameMetadata"]
frames_game = game_data["frames"]

# %%
game

# %%
# [f["rfc460Timestamp"] for f in frames_game]
last_frame_game = frames_game[-1]
last_frame_game

# %%
merged_last_frame = last_frame.copy()
merged_last_frame.update(last_frame_game)
merged_last_frame

# %%
# Merge data from match details + game window => team stats + players stats
# Last frame = final state of the game
game["final_state"] = merged_last_frame
game

# %%
game.keys()

# %%
# Refacto tout pour que ca soit plus propre maintenant
# Blue team
#   team data
#   players
#       player data
# Red team
#   team data
#   players
#       player data
from copy import deepcopy
g_data = deepcopy(game)

# %%
# 2009-07-12 11:03:12+02:00

params = dict(
    hl="en-US",
    tournamentId=103936903203607374,
)
r = rq.get("https://esports-api.lolesports.com/persisted/gw/getCompletedEvents", headers=headers, params=params)
r.json()

# %%
r.json()

# %%
params = {
    "gameId": 106926282335055890,
    # "startingTime": mydate_final
}

# r = rq.get("https://europe.api.riotgames.com/riot/account/v1/accounts/me", headers=headers)
r = rq.get("https://europe.api.riotgames.com/lol/match/v5/matches/106926282335055885", headers=headers)
r

# %%
r.json()

# %%
params = {
    "startingTime": mydate_final
}
r = rq.get("https://feed.lolesports.com/livestats/v1/details/106926282335055890", headers=headers, params=params)
r

# %%
r.json()
